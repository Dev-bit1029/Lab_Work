# %% [markdown]
# # Lab_Work 1.2

# %%
# Demonstrate sep (separator)
print("Gulabjambu", "kajuhalwa", "Halwa ", sep="  ")

# Demonstrate end (what comes at the end)
print("Hello", end=" ")
print("World")
# Out:
# Gulabjambu  kajuhalwa  Halwa
# Hello World

# %%
# Combining sep and end
print("2026", "04", "29", sep="/", end=" ")
print("Done")
# Out:
# 2026/04/29 Done

# %%
Name = str(input("Enter The Name:-"))
Age = float(input("Enter The Age:-"))
Hubby = str(input("Enter The Hubby:-"))
# Out:
# Enter The Name:- Dev Thakkar
# Enter The Age:- 20
# Enter The Hubby:- Badminton

# %%
a = int(input("Enter the Number :-"))
b = int(input("Enter the Number2 :-"))
c = a+b
print(c)
# Out:
# Enter the Number :- 23
# Enter the Number2 :- 25
# 48

# %%
a = int(input("Enter the Number :-"))
v = int(input("Enter the Number2 :-"))
d = a-v
print(d)
# Out:
# Enter the Number :- 12
# Enter the Number2 :- 10
# 2

# %%
s = int(input("Enter the Number :-"))
d = int(input("Enter the Number2 :-"))
a = s*d
print(a)
# Out:
# Enter the Number :- 45
# Enter the Number2 :- 50
# 2250

# %%
a =  int(input("Enter the Number :-"))
A = int(input("Enter the Number2 :-"))
T = a/A
print(T)
# Out:
# Enter the Number :- 12
# Enter the Number2 :- 1
# 12.0

# %%
number = int(input("Enter the Number :-"))
number2 = int(input("Enter the Number2 :-"))
NO = number+number2
print(NO)
# Out:
# Enter the Number :- 20
# Enter the Number2 :- 20
# 40

# %%
# Integer
a = 10
print(a, "->")
print(type(a))

# Float
b = 10.5
print(b, "->")
print( type(b))
# String
c = "Hello Python"
print(c, "->")
print(type(c))

# Boolean
d = True
print(d, "->")
print( type(d))

# Complex
e = 3 + 4j
print(e, "->")
print(type(e))
# Out:
# 10 ->
# <class 'int'>
# 10.5 ->
# <class 'float'>
# Hello Python ->
# <class 'str'>
# True ->
# <class 'bool'>
# (3+4j) ->
# <class 'complex'>

# %%
# take input
a = int(input("Enter number 1: "))
b = int(input("Enter number 2: "))

# and
print(a > 0 and b > 0)

# or
print(a > 0 or b > 0)

# not
print(not(a > 0))
print(not(b > 0))
# Out:
# Enter number 1:  10
# Enter number 2:  0
# False
# True
# False
# True

# %%
a = int(input("Enter number: "))

a += 5
print(a)

a -= 2
print(a)

a *= 2
print(a)

a /= 2
print(a)
# Out:
# Enter number:  10
# 15
# 13
# 26
# 13.0

# %%
Name = str(input("Enter Your Name:-"))
height = float(input("Enter your height (in meters): "))
weight = float(input("Enter your weight (in kg): "))

print("Name:", Name)
print("Height:", height)
print("Weight:", weight)
# Out:
# Enter Your Name:- DEV THAKKAR
# Enter your height (in meters):  5.5
# Enter your weight (in kg):  52
# Name: DEV THAKKAR
# Height: 5.5
# Weight: 52.0
