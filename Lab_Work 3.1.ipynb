# %% [markdown]
# # Lab_Work 3.1

# %%
print("======Welcome to Jainam Namkeen====== ")
print(" ")
print(" ")

print("___Customer Detail___")

print(" ")
print(" ")

first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
print(" ")
print(" ")
print(f"Hello, {last_name}, {first_name}!")
# Out:
# ======Welcome to Jainam Namkeen======
#
#
# ___Customer Detail___
# Enter your first name:  DEV
# Enter your last name:  THAKKAR
#
#
# Hello, THAKKAR , DEV !

# %%
item = "apple"
price = 5.50

print(f"The price of {item} is {price} dollars.")
# Out:
# The price of apple is 5.5 dollars.

# %%
text = input("Enter a string: ")

reversed_text = text[::-1]

print("Reversed String:", reversed_text)

if text == reversed_text:
    print("🔥 It is a PALINDROME!")
else:
    print("❌ It is NOT a palindrome!")
# Out:
# Enter a string:  level
# Reversed String: level
# 🔥 It is a PALINDROME!

# %%
text = input("Enter a string: ")

upper_text = text.upper()

print("Uppercase:", upper_text)
# Out:
# Enter a string:  dev thakkar
# Uppercase: DEV THAKKAR

# %%
text = input("Enter a string: ")

lower_text = text.lower()

print("Lowercase:", lower_text)
# Out:
# Enter a string:  disha thakkar
# Lowercase: disha thakkar

# %%
text = input("Enter a string: ")

title_text = text.title()

print("Title Case:", title_text)
# Out:
# Enter a string:  sweta thakkar
# Title Case: Sweta Thakkar

# %%
sentence1 = "Machine Learning and AI are trending"

position = sentence1.find("AI")
print("Position of 'AI':", position)
# Out:
# Position of 'AI': 21

# %%
sentence1 = "Machine Learning and AI are trending"


position = sentence1.find("AI")
print("Position of 'AI':", position)

new_sentence = sentence1.replace("AI", "Artificial Intelligence")
print("After Replace:", new_sentence)
# Out:
# Position of 'AI': 21
# After Replace: Machine Learning and Artificial Intelligence are trending
# Count of 'data': 3

# %%
sentence2 = "data data mining and big data"

count_data = sentence2.count("data")
print("Count of 'data':", count_data)
# Out:
# Count of 'data': 3

# %%
fruits = "apple,banana,grapes"
fruit_list = fruits.split(",")
print("Fruit List:", fruit_list)
# Out:
# Fruit List: ['apple', 'banana', 'grapes']

# %%
words = ["Python", "is", "awesome"]
sentence = " ".join(words)
print("Joined Sentence:", sentence)
# Out:
# Joined Sentence: Python is awesome

# %%
multi_text = """Python is fun
Machine Learning is powerful
AI is future"""
lines = multi_text.split("\n")

print("\n🔥 Lines one by one:")
for line in lines:
    print(line)
# Out:
# 🔥 Lines one by one:
# Python is fun
# Machine Learning is powerful
# AI is future

# %%
text1 = "Hello beautiful World"

if text1.startswith("Hello") and text1.endswith("World"):
    print("🔥 String starts with 'Hello' and ends with 'World'")
else:
    print("❌ Condition not satisfied")
# Out:
# 🔥 String starts with 'Hello' and ends with 'World'

# %%
text2 = "Data123#Science!"

clean_text = "".join(char for char in text2 if char.isalpha())
print("Cleaned String:", clean_text)
# Out:
# Cleaned String: DataScience

# %%
text3 = "Python"
reversed_text = text3[::-1]
print("Reversed String:", reversed_text)
# Out:
# Reversed String: nohtyP
